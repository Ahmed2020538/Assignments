# %% [markdown]
# # Project_description ::
# * *Project* :: Its data_analysis and ML project.
# * *Data* :: We have dataset about black_friday marketing Sales data and derive customer_behaviour and products_demands.
# * *Goal* :: The primary goal of that project go through that data and apply data analysis Process to Explorotory data to identify the Behavior of data to get ability to extract meaningfull knowlledge , insights and visions from that data to help the steckolders get ability to ake the most efficient decision to improve the Business ,,and Apply Some Visualization technices using visualize_elements like (plots , charts and maps) to identify the patterns Trends and Outliers on the data and Apply ML Algo on data to get ability to predict new data ign future.
#
# # Tools :: There are More Liberaries and framworks we wiil use it on that project.
#
#   * *Numpy*  :: To deal with 1_d array as (Vector) , 2_d array as (matrix)and multi_d array (tensor)and to apply Mathimatical_operations like Linear_Algebra operations .
#   * *Pandas* :: To load dataset and to Apply EDA Process to generate Meaningful_Knowledge , Insights and Visions from that data.
#   * *Seaborn* and Matplotlib :: To identify the Pattern , Trends and Outliers of data.
#   * *Sklearn* :: To Apply data Preprocessing process and apply ML Algo on data.
#
# # Table of Content ::
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis (EDA)</a></li>
# <li><a href="#Data_Preprocessing">Data_Preprocessing</a></li>
# <li><a href="#Machine_Learing_Algo">ML_Algo</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# # Inrto ::
# * *Data*    :: We Have dataset about Black_Friday Sales_data which Contains info of 550088 samples and 15 Feature Which Collcting from Kaggle website for Free datasets.
# * *Processing* :: We must Cleansing data well and investigate data is correct and Cleaned (Wighout Noisy , Errors  Non_logic_values , Duplicates , Missing_Values , Outliers)
# * *Processes*
#  * *Data_ingestion* ::
#      * Understanding The Objects and The domain of The Business well.
#      * Understanding The Report of the data well to identify The Labelles of Missing_Values.
#  * *Data_Acuqisition* ::
#      * Collecting The Right data which related to the Problem which we need to Solve.
#  * *Loading dataset* LL
#  * *Apply EDA Process* ::
#      * (Wrangling and Mainpulating data ) To Identify The Behaviour of the data.
#  * *Apply Data Visualization process* ::
#      * To idntify the Patterns , Trends and outliers of the data.
#  * *Apply Data_Preprocessing* ::
#      * To Handling , Cleansing Data.
#  * *Spliting_data* ::
#      * Spliting data into (Traning data For fitting Model) and (Testing data To Evaluate Model performance.
#  * *Data_scalling* ::
#     * Normalize dataset cols in the Normal_distribution Becouse Data my have deffirent Scaller.
#  * *Apply LM_Algorithms*
#  * *Traning_Model*
#     * For Fitting Model .
#  * *Evaluting_Model*
#     * For testing The performance and the score of the Model Efficiency and accuracy.
#  * *Deploy_Model*
#     * For Put The Model as Product To make user have ability To se It
#  * *Monitoring Model Performance*
#     * For identify The New Model an Updates which Make The Model More efficent For Solving our problem.

# %%
# Import Liberaries ::

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datasist as ds
import warnings as w

# %%
# Apply matplotlib in any jupyter version
# %matplotlib inline
# Ignore any Warnings
w.filterwarnings("ignore")
# Set_figure_attributies
sns.set( rc = {"figure.figsize" : [10 , 10 ]} , font_scale = 1.5)

# %%
# Loading dataset as df ::
df = pd.read_excel("black_friday.xlsx")
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# * From The result above we can see some Observations :
#     * We can Known from that cols that data belongs Marketing Business Which refer to user , city , Age , marital_statue ,kind_of_Product , Purchase.
#     * The Text Cols :: ( Gender , City_Category)
#     * The Numerical Col :: ( Age , Accupation , stay_in_current_city , Material_Statue , Product_1  _2 , _3 )
#     * The Our Target is Purchase which define actual_Output

# %% [markdown]
# # EDA_Process

# %%
# identify the dataset columns ::
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# identify dataset info ::
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %% [markdown]
# * From the result above we can see some observations ::
#     * We have 550068 Samples of data .
#     * We have 12 feature .
#
#     * The Values of clos (product_category 2 , 3) are float we may need to convert them into integer as
#     product_category_1
#     * The col of prouct_category_2 have hue num of missing values.
#     * The col of product_category_3 also have high num f missing values.

# %%
# Identify The Statistics data_details ::
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %% [markdown]
# * From The result of describe we can see some statistics observations :
#     * Occupation _Col Its Min_value is 0.000 we Shoud solve that value Becouse there aren't Occupation = zero .
#     * The Age _Col not Prepare on that describtion becouse its dtype is object not integer.

# %%
df.describe(include="object")
# Out:
#        Product_ID  Gender     Age City_Category  Stay_In_Current_City_Years
# count      550068  550068  550068        550068                      550068
# unique       3631       2       7             3                           5
# top     P00265242       M   26-35             B                           1
# freq         1880  414259  219587        231173                      193821

# %% [markdown]
# * From the result of object describtion we can see :
#     * Gender _Col  ::  have 2 unique values (F , M) and that most_frequancy is (M) .
#     * Age _Col  ::  have 7 Unique Values and The most Frequancy is (26 _35).
#     * City_Category _Co  :: l have 3 unique values and thae most frequancy (B).
#     * Stay_in_Current_City_Year _Col  ::  have 5 Unique Values and The most Frequancy (1)

# %%
# Identify the unique values of columns and the cols values count ::
for col in df.columns :
    print(f"The Col :: {col}\n\nThe uniqe_values of :: ({col}) :: {df[col].unique()}\n\nThe Value_counts of \
:: ({col}) ::\n{df[col].value_counts()}\n{'-'*80}")
# Out:
# The Col :: User_ID
#
# The uniqe_values of :: (User_ID) :: [1000001 1000002 1000003 ... 1004113 1005391 1001529]
#
# The Value_counts of :: (User_ID) ::
# 1001680    1026
# 1004277     979
# 1001941     898
# 1001181     862
# 1000889     823
#            ...
# 1000094       7
# 1002111       7
# 1004991       7
# 1005608       7
# 1000708       6
# Name: User_ID, Length: 5891, dtype: int64
# --------------------------------------------------------------------------------
# The Col :: Product_ID
#
# The uniqe_values of :: (Product_ID) :: ['P00069042' 'P00248942' 'P00087842' ... 'P00370293' 'P00371644'
#  'P00370853']
#
# The Value_counts of :: (Product_ID) ::
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00065542       1
# P00339142       1
# P00309042       1
# P00053242       1
# P00298342       1
# Name: Product_ID, Length: 3631, dtype: int64
# ...

# %% [markdown]
# * From the Result above we can see some Observations ::
#     * *User_Id and product_Id*  ::
#        * They Are not efficient Features There are uselees features with our Target.
#     * *Gender* ::
#       *That_Feature include 2 Classes (F , M) and there are imbalance Classes Becouse num of M more Large than .
#     * *Age_Feature* ::
#         * The Frist most user  in Age (26-35) age Which Num (219587).
#         * The second Most User in Age (36-45) Num (110013) and (18-25) age Num(99660).
#         * The Third most user  in Age (46-50) Num (45701)  and (51-55) Num (38501).
#         * The Low User         in age (+55)   Num (21504)  and (0-17)  Num (15102).
#     * *City_Category* ::
#         * It is have 3 Classes ( A , B , C).
#         * The most User City_Cat   in Class A Which its Num(231173).
#         * The second user City_Cat in Class C Which its Num (17175).
#         * The Third User City_Cat  in Class B Which its Num (147720).
#     * *Marital_Status* ::
#         * It is Have 2 Classes ( 0 , 1). *There are imbalanced Classes*.
#         * The Most User  in Marial_satatue (0).
#         * The Secnd User in Marial_satatue (1).
#     * *Product_Category_2* ::
#         * Its Float dtype we need to convert it into integer dtype .
#         * Its Include NaN_Values Which define (Missing_Values).
#     * *Product_Category_3* ::
#         * Its Float dtype we need to convert it into integer dtype .
#         * Its Include NaN_Values Which define (Missing_Values).

# %%
# identify The Missing values :: 
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# * Fro The Result above we can see some Observations ::
#     * All Cols not Include NaN_Values.
#     * *Expect* ::  Product_Category_2 and Product_Category_3 include hue Num of Nan_Values which define (Missing_Values)
#     * We Must Handling Missing data ::
#         * Fillna Values.
#         * Impute NaN_Values.
#         * Drop The Col Which iclude hue num of NaN_Values.

# %%
duplicates = df.duplicated()
print(duplicates ,"\n","*"*80)
df.drop_duplicates()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 550063    False
# 550064    False
# 550065    False
# 550066    False
# 550067    False
# Length: 550068, dtype: bool
#  ********************************************************************************
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# ...

# %% [markdown]
# * From The Result above we can see That ::
#     * Data no Include Duplicates.

# %% [markdown]
# # Data selection ::

# %%
df.groupby("City_Category").describe()
# Out:
#                 User_ID                                                   \
#                   count          mean          std        min        25%
# City_Category
# A              147720.0  1.002942e+06  1791.615533  1000001.0  1001255.0
# B              231173.0  1.003069e+06  1684.741781  1000004.0  1001671.0
# C              171175.0  1.003050e+06  1725.825426  1000002.0  1001561.0
#
#                                                Occupation            ...  \
#                      50%        75%        max      count      mean  ...
# City_Category                                                        ...
# A              1002986.0  1004508.0  1006034.0   147720.0  7.828364  ...
# B              1003129.0  1004446.0  1006040.0   231173.0  7.987282  ...
# C              1003119.0  1004503.0  1006038.0   171175.0  8.411789  ...
#
#               Product_Category_3        Purchase                            \
# ...

# %%
df.groupby("Gender").describe()
# Out:
#          User_ID                                                              \
#            count          mean          std        min        25%        50%
# Gender
# F       135809.0  1.003130e+06  1786.630589  1000001.0  1001569.0  1003159.0
# M       414259.0  1.002996e+06  1706.493873  1000002.0  1001505.0  1003041.0
#
#                              Occupation           ... Product_Category_3  \
#               75%        max      count     mean  ...                75%
# Gender                                            ...
# F       1004765.0  1006039.0   135809.0  6.74054  ...               16.0
# M       1004411.0  1006040.0   414259.0  8.51475  ...               16.0
#
#               Purchase                                                  \
#          max     count         mean          std   min     25%     50%
# Gender
# F       18.0  135809.0  8734.565765  4767.233289  12.0  5433.0  7914.0
# M       18.0  414259.0  9437.526040  5092.186210  12.0  5863.0  8098.0
#
#
# ...

# %%
df.groupby("Gender").describe()["Purchase"]
# Out:
#            count         mean          std   min     25%     50%      75%  \
# Gender
# F       135809.0  8734.565765  4767.233289  12.0  5433.0  7914.0  11400.0
# M       414259.0  9437.526040  5092.186210  12.0  5863.0  8098.0  12454.0
#
#             max
# Gender
# F       23959.0
# M       23961.0

# %%
df[df["Age"] < "20"]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 70      1000018  P00366542      F  18-25           3             B
# ...         ...        ...    ...    ...         ...           ...
# 550020  1005964  P00370293      M  18-25           5             B
# 550024  1005973  P00370293      M   0-17          10             C
# 550032  1005985  P00375436      F  18-25           4             C
# 550035  1005989  P00370853      F   0-17          10             C
# 550046  1006006  P00375436      F   0-17           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df[df["Age"] >"20"]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# ...

# %%
df[df["Age"] >"20"]["Purchase"]
# Out:
# 4          7969
# 5         15227
# 6         19215
# 7         15854
# 8         15686
#           ...
# 550063      368
# 550064      371
# 550065      137
# 550066      365
# 550067      490
# Name: Purchase, Length: 435306, dtype: int64

# %%
df[df["Age"] >"20"]["City_Category"]
# Out:
# 4         C
# 5         A
# 6         B
# 7         B
# 8         B
#          ..
# 550063    B
# 550064    C
# 550065    B
# 550066    C
# 550067    B
# Name: City_Category, Length: 435306, dtype: object

# %%
Age_info =df["Age"] < "20"

# %%
Age_info.value_counts()
# Out:
# False    435306
# True     114762
# Name: Age, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
df.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023971        0.020443            0.003825
# Occupation         -0.023971    1.000000        0.024280           -0.007618
# Marital_Status      0.020443    0.024280        1.000000            0.019888
# Product_Category_1  0.003825   -0.007618        0.019888            1.000000
# Product_Category_2  0.001529   -0.000384        0.015138            0.540583
# Product_Category_3  0.003419    0.013263        0.019473            0.229678
# Purchase            0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.001529            0.003419  0.004716
# Occupation                   -0.000384            0.013263  0.020833
# Marital_Status                0.015138            0.019473 -0.000463
# Product_Category_1            0.540583            0.229678 -0.343703
# ...

# %%
sns.heatmap(df.corr() , annot= True ,cmap = "viridis" , linecolor='Black' , linewidths=5 )

# %%
# identify The Correlation Features among our Target ::
cor_Target = df[df.columns].corr()['Purchase'][:-1]
cor_Target
# Out:
# User_ID               0.004716
# Occupation            0.020833
# Marital_Status       -0.000463
# Product_Category_1   -0.343703
# Product_Category_2   -0.209918
# Product_Category_3   -0.022006
# Name: Purchase, dtype: float64

# %%
# Using datasist Liberary To EDA_Process ::
ds.structdata.describe(df)
# Out:
# First five data points
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# * From Result above  We can get all info about dataframe using the datasist Lib ::
#     * The Firest Five samples.
#     * The Last Five samples.
#     * Random Five samples.
#     * dtypes of data Features.
#     * Numerical_Features.
#     * Categorical_Features.
#     * Unque_Values of Features.
#     * Num_Missing_Values.
#     * Duplicaties data_Samples.
#     * Statistic_describtion of Numerical_Features.
#     * Statistic_description of Categorical_Features.

# %% [markdown]
# # Data_Visualization_Process ::

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# # Visualize Numerical data ::

# %% [markdown]
# * univariate_plots of Numerical_data ::

# %%
# displot 
sns.distplot(df["Purchase"] , kde=False , color = "m")

# %%
# kdeplot ::
sns.kdeplot(df["Purchase"] , shade = True , color = "m")

# %% [markdown]
# * Bivariate plots of Numerical_data ::

# %%
sns.jointplot( x = "Product_Category_1" , y = "Purchase" , data = df , kind="scatter" , height=10)

# %%
sns.jointplot( x = "Product_Category_2" , y = "Purchase" , data = df , kind="scatter" , height=10)

# %%
sns.jointplot( x = "Product_Category_3" , y = "Purchase" , data = df , kind="scatter" , height=10)

# %%
sns.jointplot( x = "Product_Category_1" , y = "Purchase" , data = df , kind="hex" , height=10)

# %%
sns.jointplot( x = "Product_Category_2" , y = "Purchase" , data = df , kind="hex" , height=10)

# %%
sns.jointplot( x = "Product_Category_3" , y = "Purchase" , data = df , kind="hex" , height=10)

# %%
sns.jointplot( x = "Product_Category_1" , y = "Purchase" , data = df , kind="reg" , height=10)

# %%
sns.jointplot( x = "Product_Category_2" , y = "Purchase" , data = df , kind="reg" , height=10)

# %%
sns.jointplot( x = "Product_Category_3" , y = "Purchase" , data = df , kind="reg" , height=10)

# %%
# pairplot ::
sns.pairplot(df)

# %% [markdown]
# # Visualize Categorical_data ::

# %% [markdown]
# * univariate Categorical_data ::

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
sns.boxenplot( x= "Age" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxplot( x= "Age" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxenplot( x= "Gender" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxplot( x= "Gender" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxenplot( x= "Occupation" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxplot( x= "Occupation" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxenplot( x= "City_Category" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxplot( x= "City_Category" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxenplot( x= "Stay_In_Current_City_Years" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxplot( x= "Stay_In_Current_City_Years" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxenplot( x= "Marital_Status" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxplot( x= "Marital_Status" , y = "Purchase" , data = df , palette="viridis")

# %%
sns.boxplot( x=  "Age" , y = "Purchase" , data = df , palette="viridis" , hue="Marital_Status")

# %%
sns.boxplot( x=  "Age" , y = "Purchase" , data = df , palette="viridis" , hue="Stay_In_Current_City_Years")

# %%
sns.boxplot( x=  "Age" , y = "Purchase" , data = df , palette="viridis" , hue="City_Category")

# %%
sns.boxplot( x=  "Age" , y = "Purchase" , data = df , palette="viridis" , hue="Gender")

# %%
sns.boxplot( x=  "Occupation" , y = "Purchase" , data = df , palette="viridis" , hue="Age")

# %%
sns.stripplot( x=  "Age" , y = "Purchase" , data = df , palette="viridis" )

# %%
sns.stripplot( x=  "Age" , y = "Purchase" , data = df , palette="viridis" , hue="Gender" , dodge=True)

# %%
sns.stripplot( x=  "Gender" , y = "Purchase" , data = df , palette="viridis" )

# %%
sns.stripplot( x=  "Occupation" , y = "Purchase" , data = df , palette="viridis" )

# %%
sns.stripplot( x=  "City_Category" , y = "Purchase" , data = df , palette="viridis" )

# %%
sns.stripplot( x=  "City_Category" , y = "Purchase" , data = df , palette="rocket" , hue="Gender" )

# %%
sns.countplot("Age" , data = df , palette = "viridis")

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
sns.countplot("Gender" , data = df , palette = "viridis")

# %%
sns.countplot("Age" , data = df , palette = "viridis" , hue= "Gender")

# %%
sns.countplot("City_Category" , data = df , palette = "viridis")

# %%
sns.countplot("Age" , data = df , palette = "viridis" , hue= "City_Category")

# %%
sns.countplot("Gender" , data = df , palette = "viridis" , hue= "City_Category")

# %%
sns.countplot("Marital_Status" , data = df , palette = "viridis")

# %%
sns.countplot("Gender" , data = df , palette = "viridis" , hue= "Marital_Status")

# %%
sns.countplot("Age" , data = df , palette = "viridis" , hue= "Marital_Status")

# %%
sns.countplot("Marital_Status" , data = df , palette = "viridis" , hue= "City_Category")

# %%
sns.countplot("Occupation" , data = df , palette = "viridis")

# %%
sns.countplot("Occupation" , data = df , palette = "viridis" , hue="Gender")

# %%
sns.countplot("Occupation" , data = df , palette = "viridis" , hue="City_Category")

# %%
sns.countplot("Occupation" , data = df , palette = "viridis" , hue="Marital_Status")

# %% [markdown]
# # Preprocessing _ Process ::

# %% [markdown]
# * Identify The data non_logic_Values , Noisy and Errors .
# * Identify The duplicates and remove It .
# * Identify the Missing Values and Processing it .
# * Identify The Outliers and Processing It.
# * Processing Text data .
# * Identify The imbalanced Classes and Smote it.
# * Select_Input data Features.
# * Select Our Target.
# * Split data into Trainging and Testing data .
# * Scalling data .
# * Import ML Algo For Regression Problem .
# * Training Model (For Fitting Model) .
# * Testing Model (For Evaluating Model) .
# * Select The Most efficient Model For our Regression Problem .
# * Deploy Model .

# %%
# Identify The data non_logic_Values , Noisy and Errors .

for col in df.columns :
    print(f"The Col :: ({col})\n")
    print(f"The unique Vales of :: ({col}) :: {df[col].unique()}\n")
    print(f"The Value_Counts of  :: ({col}) ::\n{df[col].value_counts()}\n")
    print("-" * 80)
    print("-" * 80)
# Out:
# The Col :: (User_ID)
#
# The unique Vales of :: (User_ID) :: [1000001 1000002 1000003 ... 1004113 1005391 1001529]
#
# The Value_Counts of  :: (User_ID) ::
# 1001680    1026
# 1004277     979
# 1001941     898
# 1001181     862
# 1000889     823
#            ...
# 1000094       7
# 1002111       7
# 1004991       7
# 1005608       7
# 1000708       6
# Name: User_ID, Length: 5891, dtype: int64
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# The Col :: (Product_ID)
#
# The unique Vales of :: (Product_ID) :: ['P00069042' 'P00248942' 'P00087842' ... 'P00370293' 'P00371644'
#  'P00370853']
#
# The Value_Counts of  :: (Product_ID) ::
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00065542       1
# P00339142       1
# P00309042       1
# P00053242       1
# P00298342       1
# ...

# %%
# Identify The duplicates and remove It .
duplicaies = df.duplicated()
print(duplicaies)
df.drop_duplicates()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 550063    False
# 550064    False
# 550065    False
# 550066    False
# 550067    False
# Length: 550068, dtype: bool
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# ...

# %%
# Identify the Missing Values and Processing it .
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %% [markdown]
# * From The Result above we can see that :
#     * Product_Category_2 and Product_Category_3 cols include Num Of NaN_Values.
#       * On Tha Case w will Fill Nan_values using Fillna or Imputer KNNImputer or SimpleImputer

# %%
cols = ["Product_Category_2" ,"Product_Category_3"]
for col in cols :
    df[col].fillna(df[col].median() , inplace = True)

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
# Convert dtype of Product_Category_2 into integer insted of foat ::
df["Product_Category_2"] = df["Product_Category_2"].apply(lambda x : int(x))
df["Product_Category_3"] = df["Product_Category_3"].apply(lambda x : int(x))

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
# Handling the Stay_In_Current_City_Years col ::
df["Stay_In_Current_City_Years"] =  pd.to_numeric(df["Stay_In_Current_City_Years"] , errors="coerce")

# %%
df.isna().sum()
# Out:
# User_ID                           0
# Product_ID                        0
# Gender                            0
# Age                               0
# Occupation                        0
# City_Category                     0
# Stay_In_Current_City_Years    84726
# Marital_Status                    0
# Product_Category_1                0
# Product_Category_2                0
# Product_Category_3                0
# Purchase                          0
# dtype: int64

# %%
df["Stay_In_Current_City_Years"].fillna(df["Stay_In_Current_City_Years"].mode()[0] , inplace=True )

# %%
df["Stay_In_Current_City_Years"] = df["Stay_In_Current_City_Years"].apply(lambda x : int(x))

# %%
# Identify The Outliers and Processing It.
sns.boxplot( y = "Occupation", data = df , palette="viridis")
sns.stripplot( y = "Occupation", data = df , color = "r")

# %%
sns.boxplot( y = "Product_Category_1", data = df , palette="viridis")
sns.stripplot( y = "Product_Category_1", data = df , color = "r")

# %%
sns.boxplot( y = "Product_Category_2", data = df , palette="viridis")
sns.stripplot( y = "Product_Category_2", data = df , color = "r")

# %%
sns.boxplot( y = "Product_Category_3", data = df , palette="viridis")
sns.stripplot( y = "Product_Category_3", data = df , color = "r")

# %%
sns.boxplot( y = "Purchase", data = df , palette="viridis")
sns.stripplot( y = "Purchase", data = df , color = "r")

# %% [markdown]
# * From The Result above we can see some Obsrvations ::
#     * The Purchase col include hue num of outliers .
#         * On Tha Case we will replace outliers.

# %%
df["Purchase"] = df["Purchase"].apply( lambda x : round(x ,2))

# %%
# detect and Handling Outliers ::
from datasist.structdata import detect_outliers

outliers = detect_outliers(df , 0 , ["Purchase"])
Med_V = df["Purchase"].median()
df["Purchase"].iloc[outliers] = Med_V

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2              int64
# Product_Category_3              int64
# Purchase                      float64
# dtype: object

# %%
sns.boxplot( y = "Purchase", data = df , palette="viridis")
sns.stripplot( y = "Purchase", data = df , color = "r")

# %%
# Identify The imbalanced Classes and Smote it.
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
# Identify the imbalanced classes ::
for col in df.columns :
    print(f"The Col ({col})\nThe Value_Count of ({col}) :: \n{df[col].value_counts()}\n-------------------\n")
# Out:
# The Col (User_ID)
# The Value_Count of (User_ID) ::
# 1001680    1026
# 1004277     979
# 1001941     898
# 1001181     862
# 1000889     823
#            ...
# 1000094       7
# 1002111       7
# 1004991       7
# 1005608       7
# 1000708       6
# Name: User_ID, Length: 5891, dtype: int64
# -------------------
#
# The Col (Product_ID)
# The Value_Count of (Product_ID) ::
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00065542       1
# P00339142       1
# P00309042       1
# P00053242       1
# P00298342       1
# Name: Product_ID, Length: 3631, dtype: int64
# -------------------
#
# The Col (Gender)
# The Value_Count of (Gender) ::
# M    414259
# F    135809
# Name: Gender, dtype: int64
# -------------------
#
# The Col (Age)
# The Value_Count of (Age) ::
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64
# ...

# %%
Age_map = {"0-17" : 17 , "18-25" : 25 , "26-35" : 35 , "36-45" : 45 , "46-50" : 50 , "51-55" : 55 , "55+" : 60 }
Age_map
# Out:
# {'0-17': 17,
#  '18-25': 25,
#  '26-35': 35,
#  '36-45': 45,
#  '46-50': 50,
#  '51-55': 55,
#  '55+': 60}

# %%
df["Age"] = df["Age"].map(Age_map)

# %%
df
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0       1000001  P00069042      F   17          10             A
# 1       1000001  P00248942      F   17          10             A
# 2       1000001  P00087842      F   17          10             A
# 3       1000001  P00085442      F   17          10             A
# 4       1000002  P00285442      M   60          16             C
# ...         ...        ...    ...  ...         ...           ...
# 550063  1006033  P00372445      M   55          13             B
# 550064  1006035  P00375436      F   35           1             C
# 550065  1006036  P00375436      F   35          15             B
# 550066  1006038  P00375436      F   60           1             C
# 550067  1006039  P00371644      F   50           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# ...

# %%
# Drop useless Features :: 
df.drop(["User_ID" ,  "Product_ID"] , axis= 1 , inplace=True)

# %%
df
# Out:
#        Gender  Age  Occupation City_Category  Stay_In_Current_City_Years  \
# 0           F   17          10             A                           2
# 1           F   17          10             A                           2
# 2           F   17          10             A                           2
# 3           F   17          10             A                           2
# 4           M   60          16             C                           1
# ...       ...  ...         ...           ...                         ...
# 550063      M   55          13             B                           1
# 550064      F   35           1             C                           3
# 550065      F   35          15             B                           1
# 550066      F   60           1             C                           2
# 550067      F   50           0             B                           1
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df["Stay_In_Current_City_Years"] = df["Stay_In_Current_City_Years"].apply(lambda x :df["Stay_In_Current_City_Years"].mode()[0] if x == 0.0 else x )

# %%
X = df.drop("Purchase" , axis= 1)
y = df["Purchase"]

# %%
df.dtypes
# Out:
# Gender                         object
# Age                             int64
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2              int64
# Product_Category_3              int64
# Purchase                      float64
# dtype: object

# %%
df = pd.get_dummies(df , columns=["Gender" , "City_Category"]  , drop_first=True)
df
# Out:
#         Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0        17          10                           2               0
# 1        17          10                           2               0
# 2        17          10                           2               0
# 3        17          10                           2               0
# 4        60          16                           1               0
# ...     ...         ...                         ...             ...
# 550063   55          13                           1               1
# 550064   35           1                           3               0
# 550065   35          15                           1               1
# 550066   60           1                           2               0
# 550067   50           0                           1               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase  \
# ...

# %%
X = df.drop("Purchase" , axis= 1)
y = df["Purchase"]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X , y  , test_size=0.2 , random_state=44 , shuffle=True)

# %%
from sklearn.preprocessing import StandardScaler
scaller = StandardScaler()
x_train = scaller.fit_transform(x_train)
x_test = scaller.transform(x_test)

# %%
df
# Out:
#         Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0        17          10                           2               0
# 1        17          10                           2               0
# 2        17          10                           2               0
# 3        17          10                           2               0
# 4        60          16                           1               0
# ...     ...         ...                         ...             ...
# 550063   55          13                           1               1
# 550064   35           1                           3               0
# 550065   35          15                           1               1
# 550066   60           1                           2               0
# 550067   50           0                           1               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase  \
# ...

# %%
from sklearn.linear_model import LinearRegression , Ridge , Lasso , SGDRegressor , ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
Models = { "LR" : LinearRegression() ,
           "Lasso" : Lasso() ,
           "Ridge" : Ridge() ,
           "SGD"   : SGDRegressor() ,
           "Elastic" : ElasticNet() ,
           "DT"      : DecisionTreeRegressor() ,
           "RF"      : RandomForestRegressor(),
           "Xgb"     : XGBRegressor() ,
           "SVR"     : SVR()
        }

# %%
for Name , Model in Models.items() :
    print(f"The Model :: {Name}\n")
    Model.fit(x_train , y_train)
    print(f"The Traning_Score of {Name} :: {Model.score(x_train , y_train)}\n")
    print(f"The Testing_Score of {Name} :: {Model.score(x_test , y_test)}\n")
    print("-" * 80)
    print("-" * 80)
# Out:
# The Model :: LR
#
# The Traning_Score of LR :: 0.146134765681187
#
# The Testing_Score of LR :: 0.14720999921219957
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# The Model :: Lasso
#
# The Traning_Score of Lasso :: 0.14613428746643686
#
# The Testing_Score of Lasso :: 0.14721530339877753
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# The Model :: Ridge
#
# The Traning_Score of Ridge :: 0.14613476568047556
#
# The Testing_Score of Ridge :: 0.1472100013557508
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# The Model :: SGD
#
# The Traning_Score of SGD :: 0.14543290957750188
#
# ...
