# %% [markdown]
# * Task 1
# ----------
#   *  1) Using sendy_logistics.csv dataset create a new column and call it 'Temp_Diff' that calculates the difference of 'Tempreture' Column and current temperture.
# note: you can get current tempreture from searching on google.
#   * 2) Using sendy_logistics.csv dataset create a new column and call it 'Fehr_Temp' that calculates the fahrenheit tempreture from celsius 'Tempreture' Column.
# note: you can get the converting formula celsius to fahrenheit from google.

# %%
# Import Liberaries Which we use it

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import user_agents as UA
import zipcodes as Zip
from datasist.feature_engineering import haversine_distance , get_location_center
from ip2geotools.databases.noncommercial import DbIpCity as IP
from geopy.geocoders import Nominatim as Nom
from sklearn.feature_extraction.text import TfidfTransformer , CountVectorizer
# %matplotlib inline
sns.set(rc = {"figure.figsize" : [ 10 , 10]} , font_scale= 1.5)
sns.set_palette("viridis")

# %% [markdown]
# * 1) Using sendy_logistics.csv dataset create a new column and call it 'Temp_Diff' that calculates the difference of 'Tempreture' Column and current temperture.

# %%
# Loading data 

df = pd.read_csv("sendy_logistics.csv")
df.head()
# Out:
#          Order No       User Id Vehicle Type  ...  Destination Long      Rider Id  Time from Pickup to Arrival
# 0   Order_No_4211   User_Id_633         Bike  ...         36.829741  Rider_Id_432                          745
# 1  Order_No_25375  User_Id_2285         Bike  ...         36.814358  Rider_Id_856                         1993
# 2   Order_No_1899   User_Id_265         Bike  ...         36.828195  Rider_Id_155                          455
# 3   Order_No_9336  User_Id_1402         Bike  ...         36.795063  Rider_Id_855                         1341
# 4  Order_No_27883  User_Id_1737         Bike  ...         36.809817  Rider_Id_770                         1214
#
# [5 rows x 29 columns]

# %%
df.tail()
# Out:
#              Order No       User Id Vehicle Type  ...  Destination Long      Rider Id  Time from Pickup to Arrival
# 21196   Order_No_8834  User_Id_2001         Bike  ...         36.802702  Rider_Id_953                            9
# 21197  Order_No_22892  User_Id_1796         Bike  ...         36.847976  Rider_Id_155                          770
# 21198   Order_No_2831  User_Id_2956         Bike  ...         36.804800  Rider_Id_697                         2953
# 21199   Order_No_6174  User_Id_2524         Bike  ...         36.794872  Rider_Id_347                         1380
# 21200   Order_No_9836   User_Id_718         Bike  ...         36.830887  Rider_Id_177                         2128
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201 entries, 0 to 21200
# Data columns (total 29 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null int64
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null int64
# Placement - Weekday (Mo = 1)                 21201 non-null int64
# Placement - Time                             21201 non-null object
# Confirmation - Day of Month                  21201 non-null int64
# Confirmation - Weekday (Mo = 1)              21201 non-null int64
# Confirmation - Time                          21201 non-null object
# Arrival at Pickup - Day of Month             21201 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null int64
# Arrival at Pickup - Time                     21201 non-null object
# Pickup - Day of Month                        21201 non-null int64
# Pickup - Weekday (Mo = 1)                    21201 non-null int64
# Pickup - Time                                21201 non-null object
# Arrival at Destination - Day of Month        21201 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null int64
# Arrival at Destination - Time                21201 non-null object
# Distance (KM)                                21201 non-null int64
# Temperature                                  16835 non-null float64
# Precipitation in millimeters                 552 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# dtypes: float64(6), int64(13), object(10)
# memory usage: 4.7+ MB

# %% [markdown]
# * From The result above we can see The Tempureture Column include less numbers of na values so that in that case we will drop na values from it to espected error during apply function

# %%
df.columns
# Out:
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival'],
#       dtype='object')

# %%
df.dropna(subset=["Temperature"] , inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16835 entries, 0 to 21200
# Data columns (total 29 columns):
# Order No                                     16835 non-null object
# User Id                                      16835 non-null object
# Vehicle Type                                 16835 non-null object
# Platform Type                                16835 non-null int64
# Personal or Business                         16835 non-null object
# Placement - Day of Month                     16835 non-null int64
# Placement - Weekday (Mo = 1)                 16835 non-null int64
# Placement - Time                             16835 non-null object
# Confirmation - Day of Month                  16835 non-null int64
# Confirmation - Weekday (Mo = 1)              16835 non-null int64
# Confirmation - Time                          16835 non-null object
# Arrival at Pickup - Day of Month             16835 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         16835 non-null int64
# Arrival at Pickup - Time                     16835 non-null object
# Pickup - Day of Month                        16835 non-null int64
# Pickup - Weekday (Mo = 1)                    16835 non-null int64
# Pickup - Time                                16835 non-null object
# Arrival at Destination - Day of Month        16835 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    16835 non-null int64
# Arrival at Destination - Time                16835 non-null object
# Distance (KM)                                16835 non-null int64
# Temperature                                  16835 non-null float64
# Precipitation in millimeters                 552 non-null float64
# Pickup Lat                                   16835 non-null float64
# Pickup Long                                  16835 non-null float64
# Destination Lat                              16835 non-null float64
# Destination Long                             16835 non-null float64
# Rider Id                                     16835 non-null object
# Time from Pickup to Arrival                  16835 non-null int64
# dtypes: float64(6), int64(13), object(10)
# memory usage: 3.9+ MB

# %%
cur_Temp = 12
df["Temp_Diff"] = df["Temperature"].apply( lambda temp : temp - cur_Temp)

# %%
df[["Temp_Diff"]]
# Out:
#        Temp_Diff
# 0            8.4
# 1           14.4
# 3            7.2
# 4            3.4
# 5           15.2
# ...          ...
# 21196       16.6
# 21197       14.0
# 21198       17.2
# 21199        3.0
# 21200       18.9
#
# [16835 rows x 1 columns]

# %% [markdown]
# 2) Using sendy_logistics.csv dataset create a new column and call it 'Fehr_Temp' that calculates the fahrenheit tempreture from celsius 'Tempreture' Column.

# %%
df["Fehr_Temp"] = df["Temperature"].apply( lambda temp : (temp * 9 / 2 ) + 32)

# %%
df[["Fehr_Temp"]]
# Out:
#        Fehr_Temp
# 0         123.80
# 1         150.80
# 3         118.40
# 4         101.30
# 5         154.40
# ...          ...
# 21196     160.70
# 21197     149.00
# 21198     163.40
# 21199      99.50
# 21200     171.05
#
# [16835 rows x 1 columns]

# %%
df[["Temp_Diff" , "Fehr_Temp"]]
# Out:
#        Temp_Diff  Fehr_Temp
# 0            8.4     123.80
# 1           14.4     150.80
# 3            7.2     118.40
# 4            3.4     101.30
# 5           15.2     154.40
# ...          ...        ...
# 21196       16.6     160.70
# 21197       14.0     149.00
# 21198       17.2     163.40
# 21199        3.0      99.50
# 21200       18.9     171.05
#
# [16835 rows x 2 columns]

# %% [markdown]
# Task 2
# ---------
# * 1) Using ufo.csv dataset, extract Month from 'Time' and use it to create new column and call it 'IN_December', then it will have a value of '1' if the month is December and '0' otherwise.
# * 2) Using ufo.csv dataset, create new column and call it 'Time_Diff_From_WW1' that have time difference in years from the 'Time' Column and World War 1 start date that is 'July 28, 1914'.

# %%
df = pd.read_csv("ufo.csv") 
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
# City               18216 non-null object
# Colors Reported    2882 non-null object
# Shape Reported     15597 non-null object
# State              18241 non-null object
# Time               18241 non-null object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %% [markdown]
# * From The result above we can see that The dtype of Time column is Object on that case we will convert type of Time column into dattime dtype

# %%
df["Time"] = pd.to_datetime(df["Time"] )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
# City               18216 non-null object
# Colors Reported    2882 non-null object
# Shape Reported     15597 non-null object
# State              18241 non-null object
# Time               18241 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 712.7+ KB

# %% [markdown]
# 1) Using ufo.csv dataset, extract Month from 'Time' and use it to create new column and call it 'IN_December', then it will have a value of '1' if the month is December and '0' otherwise.

# %%
df["Months"] = df["Time"].dt.month

# %%
df[["Months"]]
# Out:
#        Months
# 0           6
# 1           6
# 2           2
# 3           6
# 4           4
# ...       ...
# 18236      12
# 18237      12
# 18238      12
# 18239      12
# 18240      12
#
# [18241 rows x 1 columns]

# %%
df["IN_December"] = df["Months"].apply( lambda x : 1 if x == 12 else 0)

# %%
df[["Months" , "IN_December"]]
# Out:
#        Months  IN_December
# 0           6            0
# 1           6            0
# 2           2            0
# 3           6            0
# 4           4            0
# ...       ...          ...
# 18236      12            1
# 18237      12            1
# 18238      12            1
# 18239      12            1
# 18240      12            1
#
# [18241 rows x 2 columns]

# %% [markdown]
# 2) Using ufo.csv dataset, create new column and call it 'Time_Diff_From_WW1' that have time difference in years from the 'Time' Column and World War 1 start date that is 'July 28, 1914'

# %%
from datetime import datetime as dt
df["Time"] = pd.to_datetime(df["Time"] )
WW1 = dt(1994 , 7 , 28)

df["Time_Diff_From_WW1"] = (df["Time"] - WW1) /np.timedelta64(1  , "Y")

# %%
df[["Time_Diff_From_WW1"]]
# Out:
#        Time_Diff_From_WW1
# 0              -64.154865
# 1              -64.075694
# 2              -63.446660
# 3              -63.156556
# 4              -61.274929
# ...                   ...
# 18236            6.431229
# 18237            6.431229
# 18238            6.431315
# 18239            6.431315
# 18240            6.431342
#
# [18241 rows x 1 columns]

# %% [markdown]
# Task 3
# -------------
# * 1) Using titanic_full.csv dataset, extract Mr,Miss,Mrs,etc.. from 'Name' column and use it to create new column and call it 'Title', then plot a countplot
# showing the count for each title in the dataset.
# * 2) Using sendy_logistics.csv extract user_id in a seperate column.

# %% [markdown]
# 1) Using titanic_full.csv dataset, extract Mr,Miss,Mrs,etc.. from 'Name' column and use it to create new column and call it 'Title', then plot a countplot showing the count for each title in the dataset.

# %%
df = pd.read_csv("titanic_full.csv")
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
def Title_Name (name) :
    if "Mr." in name :
        return "MR" 
    elif "Mrs." in name :
        return "MRS"
    elif "Miss." in name :
        return "MISS"
    else : 
        return "OTHER"

# %%
df["Title"] = df["Name"].apply(Title_Name)

# %%
df[["Title"]]
# Out:
#      Title
# 0       MR
# 1      MRS
# 2     MISS
# 3      MRS
# 4       MR
# ..     ...
# 886  OTHER
# 887   MISS
# 888   MISS
# 889     MR
# 890     MR
#
# [891 rows x 1 columns]

# %%
sns.countplot( x = "Title" , data = df )

# %% [markdown]
# 2) Using sendy_logistics.csv extract user_id in a seperate column

# %%
df = pd.read_csv("sendy_logistics.csv")
df
# Out:
#              Order No       User Id Vehicle Type  ...  Destination Long      Rider Id  Time from Pickup to Arrival
# 0       Order_No_4211   User_Id_633         Bike  ...         36.829741  Rider_Id_432                          745
# 1      Order_No_25375  User_Id_2285         Bike  ...         36.814358  Rider_Id_856                         1993
# 2       Order_No_1899   User_Id_265         Bike  ...         36.828195  Rider_Id_155                          455
# 3       Order_No_9336  User_Id_1402         Bike  ...         36.795063  Rider_Id_855                         1341
# 4      Order_No_27883  User_Id_1737         Bike  ...         36.809817  Rider_Id_770                         1214
# ...               ...           ...          ...  ...               ...           ...                          ...
# 21196   Order_No_8834  User_Id_2001         Bike  ...         36.802702  Rider_Id_953                            9
# 21197  Order_No_22892  User_Id_1796         Bike  ...         36.847976  Rider_Id_155                          770
# 21198   Order_No_2831  User_Id_2956         Bike  ...         36.804800  Rider_Id_697                         2953
# 21199   Order_No_6174  User_Id_2524         Bike  ...         36.794872  Rider_Id_347                         1380
# 21200   Order_No_9836   User_Id_718         Bike  ...         36.830887  Rider_Id_177                         2128
#
# [21201 rows x 29 columns]

# %%
df["User_Id"] = df["User Id"].apply(lambda x : x.split("_")[2])

# %%
df[["User Id" , "User_Id"]]
# Out:
#             User Id User_Id
# 0       User_Id_633     633
# 1      User_Id_2285    2285
# 2       User_Id_265     265
# 3      User_Id_1402    1402
# 4      User_Id_1737    1737
# ...             ...     ...
# 21196  User_Id_2001    2001
# 21197  User_Id_1796    1796
# 21198  User_Id_2956    2956
# 21199  User_Id_2524    2524
# 21200   User_Id_718     718
#
# [21201 rows x 2 columns]

# %% [markdown]
# Task 4
# ------------
# * 1) Using visitor-interests.csv dataset, from the first 50 row extract Browser, OS, Device data from 'UserAgent' column and use it to create new columns for Browser, OS, Device.
# * 2) Using visitor-interests.csv dataset, from the first 50 row extract latitude, longitude from 'IP' column.

# %% [markdown]
# 1) Using visitor-interests.csv dataset, from the first 50 row extract Browser, OS, Device data from 'UserAgent' column and use it to create new columns for Browser, OS, Device.

# %%
df = pd.read_csv("visitor-interests.csv")
df
# Out:
#                    IP                                          UserAgent  ... Languages                     Interests
# 0        1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  ...   english                         other
# 1         1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  ...      thai        blog/personal homepage
# 2       1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...  ...   english  shop/online shopping website
# 3       1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...  ...   english                       company
# 4       1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...  ...   english                       company
# ...               ...                                                ...  ...       ...                           ...
# 19921      223.62.3.2  Mozilla/5.0 (Linux; Android 6.0.1; SM-N920S Bu...  ...   english  shop/online shopping website
# 19922   223.62.67.192  Mozilla/5.0 (Linux; Android 6.0.1; SM-N920S Bu...  ...   english  shop/online shopping website
# 19923   223.73.243.82  Mozilla/5.0 (Linux; U; Android 5.1.1; zh-cn; v...  ...   chinese       educational institution
# 19924    223.73.66.65  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...  ...   english                      magazine
# 19925  223.81.193.148  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...  ...   chinese          social network/forum
#
# [19926 rows x 5 columns]

# %%
df = df.head(50)
df
# Out:
#                IP                                          UserAgent Country Languages                     Interests
# 0    1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...      TH   english                         other
# 1     1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...      TH      thai        blog/personal homepage
# 2   1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...      JP   english  shop/online shopping website
# 3   1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...      AU   english                       company
# 4   1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...      AU   english                       company
# 5    1.124.48.210  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...      AU   english                       company
# 6     1.124.48.99  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...      AU   english                       company
# 7    1.126.48.118  Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7....      AU   english                       company
# 8    1.126.48.171  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...      AU   english                       company
# 9     1.126.48.47  Mozilla/5.0 (iPhone; CPU iPhone OS 7_0_4 like ...      AU   english                       company
# 10   1.128.96.235  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...      AU   english  shop/online shopping website
# 11    1.128.96.30  Mozilla/5.0 (iPhone; CPU iPhone OS 8_1_3 like ...      AU   english                       company
# 12   1.128.97.122  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_3 like ...      AU   english                       company
# 13   1.129.96.120  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_5 like ...      AU   english                       company
# 14    1.129.96.21  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...      AU   english                        church
# 15   1.129.96.252  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_5 like ...      AU   english  shop/online shopping website
# 16    1.129.96.79  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...      AU   english                       company
# 17    1.129.96.86  Mozilla/5.0 (Linux; Android 6.0.1; SM-N915G Bu...      AU   english                       company
# 18    1.129.97.46  Mozilla/5.0 (Linux; U; Android 4.2.2; en-au; S...      AU   english                       company
# 19    1.129.97.62  Mozilla/5.0 (Windows NT 6.3; WOW64; rv:48.0) G...      AU   english        blog/personal homepage
# 20   1.132.96.125  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_4 like ...      AU   english                       company
# 21   1.132.96.203  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_1 like ...      AU   english                       company
# 22    1.132.97.60  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      AU   english                       company
# 23    1.136.97.40  Mozilla/5.0 (iPhone; CPU iPhone OS 9_2 like Ma...      AU   english                       company
# 24    1.136.97.67  Mozilla/5.0 (Linux; Android 5.1.1; SAMSUNG SM-...      AU   english                       company
# 25   1.144.96.234  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...      AU   english                       company
# 26    1.144.96.77  Mozilla/5.0 (iPhone; CPU iPhone OS 9_2 like Ma...      AU   english                       company
# 27    1.144.97.41  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...      AU   english                       company
# 28    1.152.96.14  Mozilla/5.0 (iPad; CPU OS 8_4 like Mac OS X) A...      AU   english                 company/other
# 29   1.152.96.156  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:48.0) G...      AU   english                       company
# 30   1.152.96.251  Mozilla/5.0 (Linux; Android 6.0.1; SM-N910G Bu...      AU   english                       company
# 31   1.152.97.102  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      AU   english            sport organization
# 32    1.152.97.25  Mozilla/5.0 (iPhone; CPU iPhone OS 9_2_1 like ...      AU   english                       company
# 33    1.161.13.16  Mozilla/5.0 (Linux; Android 4.3; ASUS_T00I Bui...      TW   english                       company
# 34   1.161.27.235  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      TW   english                 company/other
# 35   1.162.51.164  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...      TW   english        blog/personal homepage
# 36   1.163.208.88  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      TW   chinese          social network/forum
# 37   1.164.141.85  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      TW   chinese          social network/forum
# 38    1.164.73.87  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:48.0) ...      TW   english  shop/online shopping website
# 39   1.168.54.202  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...      TW   english                         other
# 40   1.173.31.228  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...      TW   english                       company
# 41    1.186.37.87  Mozilla/5.0 (Linux; U; Android 6.0; en-US; Len...      IN   english          social network/forum
# 42    1.186.38.82  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...      IN   english                       company
# 43   1.186.98.212  Mozilla/5.0 (Linux; Android 5.1.1; SM-J500F Bu...      IN   english  shop/online shopping website
# 44   1.187.118.90  Mozilla/5.0 (Linux; U; Android 5.1.1; en-in; R...      IN   english                       company
# 45   1.187.188.80  Mozilla/5.0 (Linux; U; Android 4.2.2; en-us; A...      IN   english                       company
# 46  1.187.196.224  Mozilla/5.0 (Linux; Android 4.1.2; GT-S7262 Bu...      IN     hindi                  news website
# 47  1.187.201.169  Mozilla/5.0 (Linux; U; Android 5.1; en-US; viv...      IN   english       educational institution
# 48  1.187.207.245  Mozilla/5.0 (Linux; U; Android 5.0.2; en-US; L...      IN   english                       company
# 49   1.187.58.245  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_5 like ...      IN   english                 company/other

# %%
def User_Agent_data(ua) :
    res = UA.parse(ua)
    Browser_Family  = res.browser.family
    Browser_Version = res.browser.version
    OS_Family       = res.os.family
    OS_Version      = res.os.version
    device_Family   = res.device.family
    device_Model    = res.device.family
    device_Brand    = res.device.brand

    return pd.Series((Browser_Family , Browser_Version , OS_Family , OS_Version , device_Family , device_Model , device_Brand ))

# %%
df[["Browser_Family" , "Browser_Version" , "OS_Family" , "OS_Version" , "device_Family" , "device_Model" 
    , "device_Brand" ]] = df["UserAgent"].apply(User_Agent_data)

# %%
df[["Browser_Family" , "Browser_Version" , "OS_Family" , "OS_Version" , "device_Family" , "device_Model" 
    , "device_Brand" ]]
# Out:
#       Browser_Family     Browser_Version OS_Family  ...        device_Family         device_Model            device_Brand
# 0             Chrome       (53, 0, 2785)   Windows  ...                Other                Other                    None
# 1             Chrome       (52, 0, 2743)   Windows  ...                Other                Other                    None
# 2             Chrome       (52, 0, 2743)   Windows  ...                Other                Other                    None
# 3             Chrome       (52, 0, 2743)   Android  ...              Nexus 9              Nexus 9  Generic_Android_Tablet
# 4      Mobile Safari              (9, 0)       iOS  ...                 iPad                 iPad                   Apple
# 5   Samsung Internet              (2, 1)   Android  ...     Samsung SM-G900I     Samsung SM-G900I                 Samsung
# 6   Samsung Internet              (4, 0)   Android  ...     Samsung SM-G900I     Samsung SM-G900I                 Samsung
# 7                 IE             (11, 0)   Windows  ...                Other                Other                    None
# 8            Firefox             (48, 0)  Mac OS X  ...                  Mac                  Mac                   Apple
# 9      Mobile Safari              (7, 0)       iOS  ...               iPhone               iPhone                   Apple
# 10  Samsung Internet              (4, 0)   Android  ...     Samsung SM-G900I     Samsung SM-G900I                 Samsung
# 11     Mobile Safari              (8, 0)       iOS  ...               iPhone               iPhone                   Apple
# 12     Mobile Safari              (9, 0)       iOS  ...               iPhone               iPhone                   Apple
# 13     Mobile Safari              (9, 0)       iOS  ...               iPhone               iPhone                   Apple
# 14            Chrome       (52, 0, 2743)  Mac OS X  ...                  Mac                  Mac                   Apple
# 15            Google  (18, 1, 132077863)       iOS  ...               iPhone               iPhone                   Apple
# 16  Samsung Internet              (4, 0)   Android  ...     Samsung SM-T355Y     Samsung SM-T355Y                 Samsung
# 17     Chrome Mobile       (52, 0, 2743)   Android  ...     Samsung SM-N915G     Samsung SM-N915G                 Samsung
# 18           Android           (4, 2, 2)   Android  ...      Samsung SM-T315      Samsung SM-T315                 Samsung
# 19           Firefox             (48, 0)   Windows  ...                Other                Other                    None
# 20     Mobile Safari              (9, 0)       iOS  ...               iPhone               iPhone                   Apple
# 21     Mobile Safari              (9, 0)       iOS  ...               iPhone               iPhone                   Apple
# 22            Chrome       (52, 0, 2743)   Windows  ...                Other                Other                    None
# 23     Mobile Safari              (9, 0)       iOS  ...               iPhone               iPhone                   Apple
# 24  Samsung Internet              (3, 3)   Android  ...     Samsung SM-G800Y     Samsung SM-G800Y                 Samsung
# 25     Mobile Safari              (9, 0)       iOS  ...                 iPad                 iPad                   Apple
# 26     Mobile Safari              (9, 0)       iOS  ...               iPhone               iPhone                   Apple
# 27  Samsung Internet              (4, 0)   Android  ...     Samsung SM-N920I     Samsung SM-N920I                 Samsung
# 28     Mobile Safari              (8, 0)       iOS  ...                 iPad                 iPad                   Apple
# 29           Firefox             (48, 0)   Windows  ...                Other                Other                    None
# 30     Chrome Mobile       (52, 0, 2743)   Android  ...     Samsung SM-N910G     Samsung SM-N910G                 Samsung
# 31            Chrome       (52, 0, 2743)   Windows  ...                Other                Other                    None
# 32     Mobile Safari              (9, 0)       iOS  ...               iPhone               iPhone                   Apple
# 33     Chrome Mobile       (53, 0, 2785)   Android  ...            Asus T00I            Asus T00I                    Asus
# 34            Chrome       (53, 0, 2785)   Windows  ...                Other                Other                    None
# 35          Chromium       (52, 0, 2743)    Ubuntu  ...                Other                Other                    None
# 36            Chrome       (52, 0, 2743)   Windows  ...                Other                Other                    None
# 37            Dragon          (36, 1, 1)   Windows  ...                Other                Other                    None
# 38           Firefox             (48, 0)   Windows  ...                Other                Other                    None
# 39            Chrome       (52, 0, 2743)   Windows  ...                Other                Other                    None
# 40            Chrome       (49, 0, 2623)   Windows  ...                Other                Other                    None
# 41        UC Browser          (11, 0, 0)   Android  ...       Lenovo A7000-a       Lenovo A7000-a                  Lenovo
# 42            Chrome       (52, 0, 2743)   Windows  ...                Other                Other                    None
# 43     Chrome Mobile       (52, 0, 2743)   Android  ...     Samsung SM-J500F     Samsung SM-J500F                 Samsung
# 44       MiuiBrowser           (2, 1, 1)   Android  ...  XiaoMi Redmi Note 3  XiaoMi Redmi Note 3                  XiaoMi
# 45           Android           (4, 2, 2)   Android  ...            A550s IPS            A550s IPS         Generic_Android
# 46     Chrome Mobile       (28, 0, 1500)   Android  ...     Samsung GT-S7262     Samsung GT-S7262                 Samsung
# 47        UC Browser          (10, 7, 2)   Android  ...            vivo Y15S            vivo Y15S                    vivo
# 48        UC Browser          (11, 0, 0)   Android  ...         Lenovo A6010         Lenovo A6010                  Lenovo
# 49     Mobile Safari              (9, 0)       iOS  ...               iPhone               iPhone                   Apple
#
# [50 rows x 7 columns]

# %%
fig =sns.countplot(x = "Browser_Family" , data = df)
fig.set_xticklabels( labels =df["Browser_Family"].value_counts().index  , rotation = 90)
# Out:
# [Text(0, 0, 'Mobile Safari'),
#  Text(0, 0, 'Chrome'),
#  Text(0, 0, 'Samsung Internet'),
#  Text(0, 0, 'Chrome Mobile'),
#  Text(0, 0, 'Firefox'),
#  Text(0, 0, 'UC Browser'),
#  Text(0, 0, 'Android'),
#  Text(0, 0, 'Dragon'),
#  Text(0, 0, 'MiuiBrowser'),
#  Text(0, 0, 'IE'),
#  Text(0, 0, 'Chromium'),
#  Text(0, 0, 'Google')]

# %%
sns.countplot(x = "OS_Family" , data = df)

# %%
Top_User_device_Models = df["device_Model"].value_counts()[:6]
Top_User_device_Models
# Out:
# Other               16
# iPhone              11
# iPad                 3
# Samsung SM-G900I     3
# Mac                  2
# Nexus 9              1
# Name: device_Model, dtype: int64

# %%
fig =sns.countplot(x = "device_Model" , data = df[df["device_Model"].isin(Top_User_device_Models.index)] )
fig.set_xticklabels( labels = Top_User_device_Models.index  , rotation = 90)
# Out:
# [Text(0, 0, 'Other'),
#  Text(0, 0, 'iPhone'),
#  Text(0, 0, 'iPad'),
#  Text(0, 0, 'Samsung SM-G900I'),
#  Text(0, 0, 'Mac'),
#  Text(0, 0, 'Nexus 9')]

# %% [markdown]
# 2) Using visitor-interests.csv dataset, from the first 50 row extract latitude, longitude from 'IP' column.

# %%
df
# Out:
#                IP                                          UserAgent  ...         device_Model            device_Brand
# 0    1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  ...                Other                    None
# 1     1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  ...                Other                    None
# 2   1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...  ...                Other                    None
# 3   1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...  ...              Nexus 9  Generic_Android_Tablet
# 4   1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...  ...                 iPad                   Apple
# 5    1.124.48.210  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...  ...     Samsung SM-G900I                 Samsung
# 6     1.124.48.99  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...  ...     Samsung SM-G900I                 Samsung
# 7    1.126.48.118  Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7....  ...                Other                    None
# 8    1.126.48.171  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...  ...                  Mac                   Apple
# 9     1.126.48.47  Mozilla/5.0 (iPhone; CPU iPhone OS 7_0_4 like ...  ...               iPhone                   Apple
# 10   1.128.96.235  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...  ...     Samsung SM-G900I                 Samsung
# 11    1.128.96.30  Mozilla/5.0 (iPhone; CPU iPhone OS 8_1_3 like ...  ...               iPhone                   Apple
# 12   1.128.97.122  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_3 like ...  ...               iPhone                   Apple
# 13   1.129.96.120  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_5 like ...  ...               iPhone                   Apple
# 14    1.129.96.21  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...  ...                  Mac                   Apple
# 15   1.129.96.252  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_5 like ...  ...               iPhone                   Apple
# 16    1.129.96.79  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...  ...     Samsung SM-T355Y                 Samsung
# 17    1.129.96.86  Mozilla/5.0 (Linux; Android 6.0.1; SM-N915G Bu...  ...     Samsung SM-N915G                 Samsung
# 18    1.129.97.46  Mozilla/5.0 (Linux; U; Android 4.2.2; en-au; S...  ...      Samsung SM-T315                 Samsung
# 19    1.129.97.62  Mozilla/5.0 (Windows NT 6.3; WOW64; rv:48.0) G...  ...                Other                    None
# 20   1.132.96.125  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_4 like ...  ...               iPhone                   Apple
# 21   1.132.96.203  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_1 like ...  ...               iPhone                   Apple
# 22    1.132.97.60  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  ...                Other                    None
# 23    1.136.97.40  Mozilla/5.0 (iPhone; CPU iPhone OS 9_2 like Ma...  ...               iPhone                   Apple
# 24    1.136.97.67  Mozilla/5.0 (Linux; Android 5.1.1; SAMSUNG SM-...  ...     Samsung SM-G800Y                 Samsung
# 25   1.144.96.234  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...  ...                 iPad                   Apple
# 26    1.144.96.77  Mozilla/5.0 (iPhone; CPU iPhone OS 9_2 like Ma...  ...               iPhone                   Apple
# 27    1.144.97.41  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...  ...     Samsung SM-N920I                 Samsung
# 28    1.152.96.14  Mozilla/5.0 (iPad; CPU OS 8_4 like Mac OS X) A...  ...                 iPad                   Apple
# 29   1.152.96.156  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:48.0) G...  ...                Other                    None
# 30   1.152.96.251  Mozilla/5.0 (Linux; Android 6.0.1; SM-N910G Bu...  ...     Samsung SM-N910G                 Samsung
# 31   1.152.97.102  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  ...                Other                    None
# 32    1.152.97.25  Mozilla/5.0 (iPhone; CPU iPhone OS 9_2_1 like ...  ...               iPhone                   Apple
# 33    1.161.13.16  Mozilla/5.0 (Linux; Android 4.3; ASUS_T00I Bui...  ...            Asus T00I                    Asus
# 34   1.161.27.235  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  ...                Other                    None
# 35   1.162.51.164  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...  ...                Other                    None
# 36   1.163.208.88  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  ...                Other                    None
# 37   1.164.141.85  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  ...                Other                    None
# 38    1.164.73.87  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:48.0) ...  ...                Other                    None
# 39   1.168.54.202  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  ...                Other                    None
# 40   1.173.31.228  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...  ...                Other                    None
# 41    1.186.37.87  Mozilla/5.0 (Linux; U; Android 6.0; en-US; Len...  ...       Lenovo A7000-a                  Lenovo
# 42    1.186.38.82  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...  ...                Other                    None
# 43   1.186.98.212  Mozilla/5.0 (Linux; Android 5.1.1; SM-J500F Bu...  ...     Samsung SM-J500F                 Samsung
# 44   1.187.118.90  Mozilla/5.0 (Linux; U; Android 5.1.1; en-in; R...  ...  XiaoMi Redmi Note 3                  XiaoMi
# 45   1.187.188.80  Mozilla/5.0 (Linux; U; Android 4.2.2; en-us; A...  ...            A550s IPS         Generic_Android
# 46  1.187.196.224  Mozilla/5.0 (Linux; Android 4.1.2; GT-S7262 Bu...  ...     Samsung GT-S7262                 Samsung
# 47  1.187.201.169  Mozilla/5.0 (Linux; U; Android 5.1; en-US; viv...  ...            vivo Y15S                    vivo
# 48  1.187.207.245  Mozilla/5.0 (Linux; U; Android 5.0.2; en-US; L...  ...         Lenovo A6010                  Lenovo
# 49   1.187.58.245  Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_5 like ...  ...               iPhone                   Apple
#
# [50 rows x 12 columns]

# %%
def IP_User_data(ip) :
    try :
        res = IP.get( ip , api_key = "free")
        Latitude  = res.latitude
        Longitude =res.langtude
        City      = res.city
        Country   = res.country
        
        return pd.Series((Latitude , Longitude , City , Country))
    except :
        return "Missing"

# %%
df[["Latitude" , "Longitude" , "City" , "Country"]] = df["IP"].apply(IP_User_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3498: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.loc._setitem_with_indexer((slice(None), indexer), value)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-043e35206523> in <module>
# ----> 1 df[["Latitude" , "Longitude" , "City" , "Country"]] = df["IP"].apply(IP_User_data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3467             self._setitem_frame(key, value)
#    3468         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3469             self._setitem_array(key, value)
#    3470         else:
#    3471             # set column
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3496                 indexer = self.loc._convert_to_indexer(key, axis=1)
#    3497                 self._check_setitem_copy()
# -> 3498                 self.loc._setitem_with_indexer((slice(None), indexer), value)
#    3499
#    3500     def _setitem_frame(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     591             # actually do the set
#     592             self.obj._consolidate_inplace()
# --> 593             self.obj._data = self.obj._data.setitem(indexer=indexer, value=value)
#     594             self.obj._maybe_update_cacher(clear=True)
#     595
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in setitem(self, **kwargs)
#     558
#     559     def setitem(self, **kwargs):
# --> 560         return self.apply("setitem", **kwargs)
#     561
#     562     def putmask(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in setitem(self, indexer, value)
#     938         # set
#     939         else:
# --> 940             values[indexer] = value
#     941
#     942         # coerce and try to infer the dtypes of the result
#
# ValueError: shape mismatch: value array of shape (50,) could not be broadcast to indexing result of shape (4,50)

# %%
df[["Latitude" , "Longitude" , "City" , "Country"]]
